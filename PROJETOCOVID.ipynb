# %% [markdown]
# <a href="https://colab.research.google.com/github/feguedes/Projetos-de-DS/blob/main/PROJETOCOVID.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style()
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv("https://raw.githubusercontent.com/feguedes/Projetos-de-DS/main/owid-covid-data.csv")

# %%
df.head()
# Out:
#   iso_code continent  ... human_development_index excess_mortality
# 0      AFG      Asia  ...                   0.511              NaN
# 1      AFG      Asia  ...                   0.511              NaN
# 2      AFG      Asia  ...                   0.511              NaN
# 3      AFG      Asia  ...                   0.511              NaN
# 4      AFG      Asia  ...                   0.511              NaN
#
# [5 rows x 60 columns]

# %%
df.shape
# Out:
# (96208, 60)

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
# ...

# %%
df.dtypes
# Out:
# iso_code                                  object
# continent                                 object
# location                                  object
# date                                      object
# total_cases                              float64
# new_cases                                float64
# new_cases_smoothed                       float64
# total_deaths                             float64
# new_deaths                               float64
# new_deaths_smoothed                      float64
# total_cases_per_million                  float64
# new_cases_per_million                    float64
# new_cases_smoothed_per_million           float64
# total_deaths_per_million                 float64
# new_deaths_per_million                   float64
# new_deaths_smoothed_per_million          float64
# reproduction_rate                        float64
# icu_patients                             float64
# icu_patients_per_million                 float64
# ...

# %%
df.date = pd.to_datetime(df.date)

# %%
(df.isnull().sum() / df.shape[0]).sort_values(ascending=False)
# Out:
# weekly_icu_admissions                    0.990916
# weekly_icu_admissions_per_million        0.990916
# weekly_hosp_admissions                   0.984315
# weekly_hosp_admissions_per_million       0.984315
# excess_mortality                         0.964598
# icu_patients                             0.899728
# icu_patients_per_million                 0.899728
# people_fully_vaccinated_per_hundred      0.883752
# people_fully_vaccinated                  0.883752
# hosp_patients                            0.875364
# hosp_patients_per_million                0.875364
# new_vaccinations                         0.871674
# people_vaccinated                        0.853900
# people_vaccinated_per_hundred            0.853900
# total_vaccinations_per_hundred           0.846323
# total_vaccinations                       0.846323
# new_vaccinations_smoothed_per_million    0.735022
# new_vaccinations_smoothed                0.735022
# total_tests                              0.552875
# ...

# %%
df.loc[df.date == '2021-06-16'].sort_values(by='total_cases', ascending=False)
df.loc[df.date == '2021-06-16'].sort_values(by='total_deaths', ascending=False)
# Out:
#        iso_code      continent  ... human_development_index excess_mortality
# 94864  OWID_WRL            NaN  ...                   0.737              NaN
# 29449  OWID_EUR            NaN  ...                     NaN              NaN
# 80464  OWID_SAM            NaN  ...                     NaN              NaN
# 64046  OWID_NAM            NaN  ...                     NaN              NaN
# 5037   OWID_ASI            NaN  ...                     NaN              NaN
# ...         ...            ...  ...                     ...              ...
# 56654       FSM        Oceania  ...                   0.620              NaN
# 72894       KNA  North America  ...                   0.779              NaN
# 74025       WSM        Oceania  ...                   0.715              NaN
# 79029       SLB        Oceania  ...                   0.567              NaN
# 93296       VAT         Europe  ...                     NaN              NaN
#
# [207 rows x 60 columns]

# %%
df_paises = df.loc[df.date == '2021-06-16'].sort_values(by='total_cases', ascending=False)

# %%
df_paises.head(15)
# Out:
#        iso_code      continent  ... human_development_index excess_mortality
# 94864  OWID_WRL            NaN  ...                   0.737              NaN
# 5037   OWID_ASI            NaN  ...                     NaN              NaN
# 29449  OWID_EUR            NaN  ...                     NaN              NaN
# 64046  OWID_NAM            NaN  ...                     NaN              NaN
# 91689       USA  North America  ...                   0.926              NaN
# 29960  OWID_EUN            NaN  ...                     NaN              NaN
# 80464  OWID_SAM            NaN  ...                     NaN              NaN
# 40287       IND           Asia  ...                   0.645              NaN
# 12722       BRA  South America  ...                   0.765              NaN
# 31685       FRA         Europe  ...                   0.901              NaN
# 89055       TUR           Asia  ...                   0.820              NaN
# ...

# %% [markdown]
# Total de casos:
# * USA : 33.498.468
# * BRA : 17.628.588
# * FRA : 5.809.319
# * TUR : 5.348.249
# * RUS : 5.189.260

# %%
df_mortes = df.loc[df.date == '2021-06-16'].sort_values(by='total_deaths', ascending=False)

# %%
df_mortes.head(15)
# Out:
#        iso_code      continent  ... human_development_index excess_mortality
# 94864  OWID_WRL            NaN  ...                   0.737              NaN
# 29449  OWID_EUR            NaN  ...                     NaN              NaN
# 80464  OWID_SAM            NaN  ...                     NaN              NaN
# 64046  OWID_NAM            NaN  ...                     NaN              NaN
# 5037   OWID_ASI            NaN  ...                     NaN              NaN
# 29960  OWID_EUN            NaN  ...                     NaN              NaN
# 91689       USA  North America  ...                   0.926              NaN
# 12722       BRA  South America  ...                   0.765              NaN
# 40287       IND           Asia  ...                   0.645              NaN
# 56507       MEX  North America  ...                   0.779              NaN
# 68984       PER  South America  ...                   0.777              NaN
# ...

# %% [markdown]
# Total de mortes:
# * USA - 600.653
# * BRA - 493.693
# * IND - 381.903
# * MEX - 230.624
# * PER - 189.261
